# %%
import urllib.request, json

def get_flyer_id(location_zip_code):
    url = "https://api.flipp.com/flyerkit/v4.0/publications/jewelosco?access_token=aedcc3dc3afc882f187dbdd32b6db995&locale=en-US&postal_code="+location_zip_code
    dl = []
    with urllib.request.urlopen(url) as url:
        data = json.load(url)
        for item in data:
            if(item['name'] == 'Weekly Ad'):
                dl.append(item['id'])
    if(len(dl) > 0):
        return(dl[0])

# %%
import urllib.request, json
import csv
import pandas as pd

location = "60502"

flyer_id = get_flyer_id(location)

base_url = "https://dam.flippenterprise.net/flyerkit/publication/"+str(flyer_id)+"/products?display_type=all&source=hosted2&locale=en&access_token=aedcc3dc3afc882f187dbdd32b6db995"

data_list = []

with urllib.request.urlopen(base_url) as url:
    data = json.load(url)
    for item in data:
        temp_dict = {}
        temp_dict['ID'] = item['id']
        temp_dict['name'] = item['name']
        temp_dict['valid_from'] = item['valid_from']
        temp_dict['valid_to'] = item['valid_to']
        temp_dict['price'] = item['price_text']
        data_list.append(temp_dict)

json_object = json.dumps(data_list)
   
master_df = pd.read_json(json_object)
master_df.head()
# Out:
# C:\Users\Karthik\AppData\Local\Temp\ipykernel_23508\2824242712.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# C:\Users\Karthik\AppData\Local\Temp\ipykernel_23508\2824242712.py:26: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   master_df = pd.read_json(json_object)
#           ID                                               name  valid_from  \
# 0  822741539                                       Squash Saute  2024-02-21
# 1  822741350                                             Soleil  2024-02-21
# 2  822739454                     Chicago Blackhawks Prize Vault  2024-02-21
# 3  822740542  Special K Bars 5.28 oz., Homestyle Rice Krispi...  2024-02-21
# 4  822742562                       SunChips or Popcorners Chips  2024-02-21
#
#      valid_to price
# 0  2024-02-27
# 1  2024-02-27  7.99
# 2  2024-02-27
# 3  2024-02-27  7.00
# 4  2024-02-27  3.99
